# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = [1, 2, 3, 4, 5]
y = [1, 8, 3, 6, 5]
z = [1, 5, 3, 8, 9]

ax.scatter(x, y, z)
plt.show()

# %%
import numpy as np
import csv
csv_file = open("CSVs/SaveData.csv","r",encoding="ms932",errors="",newline="")
#リスト形式にする
f = csv.reader(csv_file,delimiter=",", doublequote=True, lineterminator="\r\n", quotechar='"', skipinitialspace=True)
#辞書形式
#f = csv.DictReader(csv_file)
#f = csv.reader(csv_file, delimiter=",", doublequote=True, lineterminator="\r\n", quotechar='"', skipinitialspace=True)
header = next(f)
print(header)
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
x = []
y = []
z = []
for row in f:
    #rowはList
    #row[0]で必要な項目を取得することができる
    #print(row)
    x.append(float(row[0]))
    y.append(float(row[1]))
    z.append(float(row[2]))
print(x)
print(y)
ax.scatter(x, y, z)
plt.show()
# Out:
# ['x', 'y', 'z']
# [-0.06330584, 0.002565332, 0.06778531, -0.1319828, -0.06305891, 0.002626404, 0.06778572, 0.1343971, -0.1319828, -0.06305917, 0.002626553, 0.06778572, 0.1343969, -0.1319827, -0.06305903, 0.002626382, 0.06778572, 0.1343971, -0.1319823, -0.06305888, 0.002626404, 0.06778572, 0.1343969, -0.1319829, -0.06305902, 0.002626367, 0.06778572, 0.1343973, -0.1319827, -0.06305902, 0.002626359, 0.06778572, 0.1343971, -0.1319831, -0.06305921, 0.002626352, 0.06778572, 0.1343972, -0.1319821, -0.06305879, 0.002626359, 0.06778572, 0.1343973, -0.1319821, -0.06305905, 0.002626412, 0.06778572, 0.1343972, -0.131983, -0.06305905, 0.002626397, 0.06778572, 0.1343973, -0.1319821, -0.06305903, 0.002626397, 0.06778572, 0.1343971, -0.1319824, -0.063059, 0.002626479, 0.06778572, 0.1343973, -0.1319823, -0.06305891, 0.002626441, 0.06778572, 0.1343971, -0.131982, -0.06305899, 0.002626352, 0.06778572, 0.1343971, -0.131982, -0.06306589, 0.002618685, 0.0677857, 0.134397, -0.1335325, -0.06379437, 0.002266556, 0.06778451, 0.1349118, -0.0661937, 0.00124646, 0.06778059, 0.0]
# [0.4780848, 0.4887953, 0.4780748, 0.5307393, 0.5670786, 0.5754371, 0.5670738, 0.5307443, 0.6157167, 0.6505439, 0.6585634, 0.6505506, 0.6157261, 0.699186, 0.7325313, 0.7402027, 0.7325336, 0.6991901, 0.7812361, 0.8131226, 0.8204575, 0.8131186, 0.7812402, 0.86194, 0.8923973, 0.8994032, 0.8923973, 0.86194, 0.9413953, 0.9704398, 0.977121, 0.9704398, 0.9413989, 1.019666, 1.047321, 1.053685, 1.047323, 1.01967, 1.09684, 1.123122, 1.129166, 1.123119, 1.096833, 1.172969, 1.197897, 1.203634, 1.197894, 1.172966, 1.248121, 1.27172, 1.277149, 1.271719, 1.248121, 1.322376, 1.344652, 1.349777, 1.344649, 1.322374, 1.395777, 1.416751, 1.421578, 1.416752, 1.395774, 1.468392, 1.488076, 1.492605, 1.488076, 1.468392, 1.540274, 1.558681, 1.562915, 1.558681, 1.540272, 1.611477, 1.628569, 1.632452, 1.628562, 1.611477, 1.675115, 1.69301, 1.69678, 1.69301, 1.675115, 1.74732, 1.753038, 1.747321, 1.071]

# %%
for row in f:
  print(row[0])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.scatter(x, y, z)
plt.show()
# Out:
# [1, 2, 3, 4, 5]
